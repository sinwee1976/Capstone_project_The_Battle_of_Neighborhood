# %%
# import libraries 
import requests
import pandas as pd
import numpy as np
import wget

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# <B><B>----------------------------------------------------------------------------------------------------------------------</B></B>

# %% [markdown]
# ## Part 1: Converting the data into a Pandas Dataframe

# %% [markdown]
# ### Step 1: Import 'london_poverty_rate.csv' and 'london_geospatial_data.csv' into the notebook

# %%
poverty_data = pd.read_csv('london_poverty_rate.csv')
poverty_data
# Out:
#                   borough   poverty_rate
# 0                  Bromley            15
# 1     Richmond upon Thames            15
# 2                   Bexley            16
# 3           City of London            16
# 4                   Sutton            16
# 5                 Havering            17
# 6     Kingston upon Thames            18
# 7                   Merton            20
# 8                  Croydon            22
# 9               Hillingdon            22
# 10              Wandsworth            22
# 11                  Barnet            23
# 12                  Harrow            23
# 13                Hounslow            25
# 14               Redbridge            25
# 15               Greenwich            26
# 16                Lewisham            26
# 17                 Enfield            27
# 18    Barking and Dagenham            28
# 19  Kensington and Chelsea            28
# 20          Waltham Forest            28
# 21                  Ealing            29
# ...

# %%
geospatial_data = pd.read_csv('london_geospatial_data.csv')
geospatial_data
# Out:
#                   borough    latitude  longitude
# 0     Barking and Dagenham  51.546483    0.129350
# 1                   Barnet  51.625150   -0.152936
# 2                   Bexley  51.451902    0.117179
# 3                    Brent  51.567281   -0.271057
# 4                  Bromley  51.367971    0.070062
# 5                   Camden  51.551706   -0.158826
# 6           City of London  51.512344   -0.090985
# 7                  Croydon  51.367971   -0.070062
# 8                   Ealing  51.525026   -0.341500
# 9                  Enfield  51.662293   -0.118066
# 10               Greenwich  51.483462    0.058620
# 11                 Hackney  51.551795   -0.064644
# 12  Hammersmith and Fulham  51.499017   -0.229150
# 13                Haringey  51.590611   -0.110971
# 14                  Harrow  51.588141   -0.342274
# 15                Havering  51.577924    0.212083
# 16              Hillingdon  51.535183   -0.448138
# 17                Hounslow  51.482836   -0.388206
# ...

# %% [markdown]
# ### Step 2: Merge 'poverty_data' and 'geospatial_data' into 'london_data'
# <B>Purpose:</B> the prupose of this step is to merge both dataframes so that we can visualise the poverty coverage in London
